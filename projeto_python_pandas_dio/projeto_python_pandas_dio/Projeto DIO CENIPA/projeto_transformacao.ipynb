# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['###!','####','*****','***', '****','NULL']

df= pd.read_csv("ocorr_cenipa.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# ...

# %%
schema = pa.DataFrameSchema(
      columns =  {
          "codigo_ocorrencia": pa.Column(pa.Int),
          "codigo_ocorrencia2": pa.Column(pa.Int),
          "ocorrencia_classificacao": pa.Column(pa.String),
          "ocorrencia_cidade": pa.Column(pa.String),
          "ocorrencia_uf": pa.Column(pa.String, nullable=True),
          "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True),
          "ocorrencia_dia": pa.Column(pa.DateTime),
          "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
          "total_recomendacoes": pa.Column(pa.Int),
      }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes#verifica os tipos de dados daas colunas
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.loc[1]#pesquisando os dados da segunda linha por LABEL(campo)
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[1]#pesquisando os dados da segunda linha por INDEX(indice) - O idence pode ser alterado
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df.iloc[-1]#pesquisando a ultima linha da coluna através do indice
# Out:
# codigo_ocorrencia                         80259
# codigo_ocorrencia2                        80259
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                      CAMPINAS
# ocorrencia_uf                                SP
# ocorrencia_aerodromo                       SBKP
# ocorrencia_dia              2021-08-18 00:00:00
# ocorrencia_hora                        12:45:00
# total_recomendacoes                           0
# Name: 6113, dtype: object

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6112              80257               80257                 ACIDENTE
# 6113              80259               80259                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 6109            RECIFE            PE                 SBRF     2021-08-15
# 6110       PORTO VELHO            RO                 SBPV     2021-08-16
# 6111             BELÉM            PA                 SBBE     2021-08-17
# 6112        DOM AQUINO            MT                  NaN     2021-08-18
# 6113          CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 6109        15:05:00                    0
# ...

# %%
df.iloc[10:15]#pesquisa por um range de indice entre o 10 a 14, sendo que indicie inclui o zero
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# ...

# %%
df.loc[10:15]#pesquisa por um range de indice entre o 10 a 15, sendo que indicie não inclui o zero
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# ...

# %%
df.loc[:,'ocorrencia_uf']#pesquisa que retorna todos os dados da COLUNA UF
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
df['ocorrencia_uf']#pesquisa que retorna todos dados da COLUNA UF sendo que sem usar a função "LOC"
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 6109    PE
# 6110    RO
# 6111    PA
# 6112    MT
# 6113    SP
# Name: ocorrencia_uf, Length: 6114, dtype: object

# %%
df.isna().sum()#função para a somar os valores nulos de todas as linhas e Colunas
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()#função para a somar os valores nulos de todas as linhas e Colunas
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.ocorrencia_uf.isnull() #pesquisa da coluna "ocorrencia_uf" onde os valores são nulos
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6109    False
# 6110    False
# 6111    False
# 6112    False
# 6113    False
# Name: ocorrencia_uf, Length: 6114, dtype: bool

# %%
filtro_uf = df.ocorrencia_uf.isnull()
df.loc[filtro_uf] #pesquisa da campos da coluna "ocorrencia_uf" onde os valores são nulos (criado uma variavel para função, chamado de FILTRO_UF)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
# 5855              79956               79956                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
# 5855      NÃO IDENTIFICADA           NaN                  NaN     2021-02-26
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0
# 5855        11:00:00                    0

# %%
filtro_aero = df.ocorrencia_aerodromo.isnull() #Filtro para a coluna Aerodromo
df.loc[filtro_aero]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6092              80236               80236                 ACIDENTE
# 6093              80227               80227                 ACIDENTE
# 6096              80229               80229                INCIDENTE
# 6099              80233               80233                 ACIDENTE
# 6112              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro_hora = df.ocorrencia_hora.isnull() #Filtro para a coluna Hora
df.loc[filtro_hora]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 4102              78823               78823                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 4102           CORUMBÁ            MS                  NaN     2017-07-09
#
#      ocorrencia_hora  total_recomendacoes
# 4102             NaN                    0

# %%
df.count()#função para contar não inclui os 'NULOS'
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6112
# ocorrencia_aerodromo        3658
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
# dtype: int64

# %%
#ocorrências cujo campo total_recomendacoes seja maior que 10 recomendações 
filtro_recomendacoes = df.total_recomendacoes > 10
df.loc[filtro_recomendacoes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2797              52265               52265                 ACIDENTE
# 3932              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
#ocorrências cujo as cidades onde o total_recomendacoes seja maior que 10 recomendações 
filtro_recomendacoes = df.total_recomendacoes > 10
df.loc[filtro_recomendacoes, 'ocorrencia_cidade']
# Out:
# 63                 SÃO PAULO
# 326           RIO DE JANEIRO
# 530                SÃO PAULO
# 727                 ITÁPOLIS
# 872                   RECIFE
# 884     SÃO JOSÉ DOS PINHAIS
# 1062              UBERLÂNDIA
# 1972                BRASÍLIA
# 2797                  SANTOS
# 3932                 VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
#ocorrências cujo as cidades onde o total_recomendacoes seja maior que 10 recomendações 
filtro_recomendacoes = df.total_recomendacoes > 10
df.loc[filtro_recomendacoes, ['ocorrencia_cidade','total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
#ocorrências cujo a classificação é igual a INCIDENTE GRAVE 
filtro_classificacao = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro_classificacao, 'ocorrencia_classificacao']
# Out:
# 0       INCIDENTE GRAVE
# 1       INCIDENTE GRAVE
# 2       INCIDENTE GRAVE
# 3       INCIDENTE GRAVE
# 4       INCIDENTE GRAVE
#              ...
# 6109    INCIDENTE GRAVE
# 6110    INCIDENTE GRAVE
# 6111    INCIDENTE GRAVE
# 6112    INCIDENTE GRAVE
# 6113    INCIDENTE GRAVE
# Name: ocorrencia_classificacao, Length: 6114, dtype: object

# %%
#ocorrências cujo a classificação é igual a INCIDENTE GRAVE , com a cidade e total de recomendações 
filtro_classificacao = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro_classificacao,[ 'ocorrencia_classificacao','ocorrencia_cidade','total_recomendacoes']]
# Out:
#      ocorrencia_classificacao   ocorrencia_cidade  total_recomendacoes
# 0             INCIDENTE GRAVE      RIO DE JANEIRO                    0
# 1             INCIDENTE GRAVE               BELÉM                    0
# 2             INCIDENTE GRAVE      RIO DE JANEIRO                    0
# 3             INCIDENTE GRAVE  LUCAS DO RIO VERDE                    0
# 4             INCIDENTE GRAVE             PELOTAS                    0
# ...                       ...                 ...                  ...
# 6109          INCIDENTE GRAVE              RECIFE                    0
# 6110          INCIDENTE GRAVE         PORTO VELHO                    0
# 6111          INCIDENTE GRAVE               BELÉM                    0
# 6112          INCIDENTE GRAVE          DOM AQUINO                    0
# 6113          INCIDENTE GRAVE            CAMPINAS                    0
#
# [6114 rows x 3 columns]

# %%
#ocorrências cujo a classificação é igual a INCIDENTE GRAVE , todos os campos 
filtro_classificacao = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro_classificacao]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211          INCIDENTE GRAVE
# 1                 40349               40349          INCIDENTE GRAVE
# 2                 40351               40351          INCIDENTE GRAVE
# 3                 39527               39527          INCIDENTE GRAVE
# 4                 40324               40324          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6109              80245               80245          INCIDENTE GRAVE
# 6110              80247               80247          INCIDENTE GRAVE
# 6111              80251               80251          INCIDENTE GRAVE
# 6112              80257               80257          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a classificação é igual a INCIDENTE GRAVE e o UF é SÃO PA, todos os campos (OPERADOR "E") 
filtro_classificacao = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_uf = df.ocorrencia_uf == 'SP'
df.loc[filtro_classificacao & filtro_uf ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069          INCIDENTE GRAVE
# 16                39809               39809          INCIDENTE GRAVE
# 18                39828               39828          INCIDENTE GRAVE
# 26                39847               39847          INCIDENTE GRAVE
# 27                39768               39768          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6084              80234               80234          INCIDENTE GRAVE
# 6085              80208               80208          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a classificação é igual a INCIDENTE GRAVE ou  UF é SÃO PA, todos os campos (OPERADOR "OU")
filtro_classificacao = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro_uf = df.ocorrencia_uf == 'SP'
df.loc[filtro_classificacao | filtro_uf ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211          INCIDENTE GRAVE
# 1                 40349               40349          INCIDENTE GRAVE
# 2                 40351               40351          INCIDENTE GRAVE
# 3                 39527               39527          INCIDENTE GRAVE
# 4                 40324               40324          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6109              80245               80245          INCIDENTE GRAVE
# 6110              80247               80247          INCIDENTE GRAVE
# 6111              80251               80251          INCIDENTE GRAVE
# 6112              80257               80257          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a classificação == INCIDENTE GRAVE ou classificação == ACIDENTE e UF é SÃO PA, todos os campos (OPERADOR "OU")
filtro_classificacao = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro_uf = df.ocorrencia_uf == 'SP'
df.loc[filtro_classificacao & filtro_uf ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069          INCIDENTE GRAVE
# 16                39809               39809          INCIDENTE GRAVE
# 18                39828               39828          INCIDENTE GRAVE
# 26                39847               39847          INCIDENTE GRAVE
# 27                39768               39768          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6084              80234               80234          INCIDENTE GRAVE
# 6085              80208               80208          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a classificação == INCIDENTE GRAVE ou classificação == ACIDENTE e UF é SÃO PA, todos os campos (OPERADOR "OU")
filtro_classificacao.isin(['INCIDENTE GRAVE','INCIDENTE']) #Outra forma trabalhar o "OU" com o operador "ISIN"
filtro_uf = df.ocorrencia_uf == 'SP'
df.loc[filtro_classificacao & filtro_uf ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069          INCIDENTE GRAVE
# 16                39809               39809          INCIDENTE GRAVE
# 18                39828               39828          INCIDENTE GRAVE
# 26                39847               39847          INCIDENTE GRAVE
# 27                39768               39768          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6084              80234               80234          INCIDENTE GRAVE
# 6085              80208               80208          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a cidade começem com a letra "C"
filtro_cidade = df.ocorrencia_cidade.str[0] =='C'
df.loc[filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215          INCIDENTE GRAVE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315          INCIDENTE GRAVE
# 20                40310               40310          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6094              80225               80225          INCIDENTE GRAVE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6100              80235               80235          INCIDENTE GRAVE
# 6113              80259               80259          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a cidade terminam com a letra "A"
filtro_cidade = df.ocorrencia_cidade.str[-1] =='A'
df.loc[filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414          INCIDENTE GRAVE
# 15                39315               39315          INCIDENTE GRAVE
# 25                39772               39772          INCIDENTE GRAVE
# 26                39847               39847          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6093              80227               80227          INCIDENTE GRAVE
# 6094              80225               80225          INCIDENTE GRAVE
# 6102              80240               80240          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a cidade terminam com os caracteres "MA"
filtro_cidade = df.ocorrencia_cidade.str[-2:] =='MA'
df.loc[filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315          INCIDENTE GRAVE
# 408               43062               43062          INCIDENTE GRAVE
# 688               44198               44198          INCIDENTE GRAVE
# 1035              51785               51785          INCIDENTE GRAVE
# 1377              45939               45939          INCIDENTE GRAVE
# 1401              46180               46180          INCIDENTE GRAVE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799          INCIDENTE GRAVE
# 2646              80059               80059          INCIDENTE GRAVE
# 2657              51347               51347          INCIDENTE GRAVE
# 2857              52340               52340          INCIDENTE GRAVE
# 2968              52832               52832          INCIDENTE GRAVE
# ...

# %%
#ocorrências cujo a cidade contem os caracteres "MA"
filtro_cidade = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507          INCIDENTE GRAVE
# 15                39315               39315          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6075              80205               80205          INCIDENTE GRAVE
# 6086              80212               80212          INCIDENTE GRAVE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227          INCIDENTE GRAVE
# 6106              80249               80249          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cujo a cidade contem os caracteres "MA"
filtro_cidade = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro_cidade]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807          INCIDENTE GRAVE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507          INCIDENTE GRAVE
# 15                39315               39315          INCIDENTE GRAVE
# 17                39810               39810          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6075              80205               80205          INCIDENTE GRAVE
# 6086              80212               80212          INCIDENTE GRAVE
# 6090              80221               80221          INCIDENTE GRAVE
# 6093              80227               80227          INCIDENTE GRAVE
# 6106              80249               80249          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências do ano de 2015
filtro_dia = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2998              52992               52992          INCIDENTE GRAVE
# 2999              52979               52979          INCIDENTE GRAVE
# 3000              53073               53073          INCIDENTE GRAVE
# 3001              53074               53074          INCIDENTE GRAVE
# 3002              52976               52976          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 3464              60632               60632          INCIDENTE GRAVE
# 3465              60600               60600          INCIDENTE GRAVE
# 3466              60642               60642          INCIDENTE GRAVE
# 3467              60631               60631          INCIDENTE GRAVE
# 3468              60649               60649          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências do ano de 2015 e mês 12
filtro_dia_ano = df.ocorrencia_dia.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia.dt.month == 12
df.loc[filtro_dia_ano & filtro_dia_mes]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53573               53573          INCIDENTE GRAVE
# 3431              60601               60601          INCIDENTE GRAVE
# 3432              53634               53634          INCIDENTE GRAVE
# 3433              53636               53636          INCIDENTE GRAVE
# 3434              53575               53575          INCIDENTE GRAVE
# 3435              60637               60637          INCIDENTE GRAVE
# 3436              53625               53625          INCIDENTE GRAVE
# 3437              53626               53626          INCIDENTE GRAVE
# 3438              53628               53628          INCIDENTE GRAVE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631          INCIDENTE GRAVE
# 3441              60636               60636          INCIDENTE GRAVE
# 3442              53627               53627          INCIDENTE GRAVE
# ...

# %%
#ocorrências do ano de 2015 e mês 12 - outra forma de pesquisar com o 'E'
filtro_dia = (df.ocorrencia_dia.dt.year == 2015) & (df.ocorrencia_dia.dt.month == 12)
df.loc[filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53573               53573          INCIDENTE GRAVE
# 3431              60601               60601          INCIDENTE GRAVE
# 3432              53634               53634          INCIDENTE GRAVE
# 3433              53636               53636          INCIDENTE GRAVE
# 3434              53575               53575          INCIDENTE GRAVE
# 3435              60637               60637          INCIDENTE GRAVE
# 3436              53625               53625          INCIDENTE GRAVE
# 3437              53626               53626          INCIDENTE GRAVE
# 3438              53628               53628          INCIDENTE GRAVE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631          INCIDENTE GRAVE
# 3441              60636               60636          INCIDENTE GRAVE
# 3442              53627               53627          INCIDENTE GRAVE
# ...

# %%
#ocorrências do ano de 2015 e mês 12 e dia 8
filtro_dia_ano = df.ocorrencia_dia.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia_dia = df.ocorrencia_dia.dt.day == 8
df.loc[filtro_dia_ano & filtro_dia_mes & filtro_dia_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3438              53628               53628          INCIDENTE GRAVE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631          INCIDENTE GRAVE
# 3441              60636               60636          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3438             AGUAÍ            SP                  NaN     2015-12-08
# 3439             JALES            SP                 SDJL     2015-12-08
# 3440          CAMPINAS            SP                 SBKP     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3438        14:30:00                    1
# 3439        10:20:00                    0
# 3440        16:19:00                    0
# 3441        13:00:00                    0

# %%
#ocorrências do ano de 2015 e mês 12, onde o dia é maior ou igual a 3 e menor ou igual a 8
filtro_dia_ano = df.ocorrencia_dia.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia_dia = (df.ocorrencia_dia.dt.day >= 3) & (df.ocorrencia_dia.dt.day <=8)
df.loc[filtro_dia_ano & filtro_dia_mes & filtro_dia_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575          INCIDENTE GRAVE
# 3435              60637               60637          INCIDENTE GRAVE
# 3436              53625               53625          INCIDENTE GRAVE
# 3437              53626               53626          INCIDENTE GRAVE
# 3438              53628               53628          INCIDENTE GRAVE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631          INCIDENTE GRAVE
# 3441              60636               60636          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
#ocorrências do ano de 2015 e mês 12, onde o dia é maior ou igual a 3 e menor ou igual a 8
filtro_dia_ano = df.ocorrencia_dia.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia_dia = (df.ocorrencia_dia.dt.day > 2) & (df.ocorrencia_dia.dt.day < 9)
df.loc[filtro_dia_ano & filtro_dia_mes & filtro_dia_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
#ocorrências do ano de 2015 e mês 12, onde o dia é maior ou igual a 3 e menor ou igual a 8
filtro_dia_ano = df.ocorrencia_dia.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia.dt.day > 2
filtro_dia_fim = df.ocorrencia_dia.dt.day < 9
df.loc[filtro_dia_ano & filtro_dia_mes & filtro_dia_inicio & filtro_dia_fim ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
#Concatenando ocorrencias dia e hora com saida de texto

df['ocorrencia_dia_hora'] = df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora

# %%
#Concatenando ocorrencias dia e hora com saida de date_time (Saida do tipo Data)

df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora
# Out:
# 0       2010-01-03 12:00:00
# 1       2010-01-03 11:05:00
# 2       2010-01-03 03:00:00
# 3       2010-01-04 17:30:00
# 4       2010-01-05 19:25:00
#                ...
# 6109    2021-08-15 15:05:00
# 6110    2021-08-16 02:30:00
# 6111    2021-08-17 15:45:00
# 6112    2021-08-18 16:00:00
# 6113    2021-08-18 12:45:00
# Length: 6114, dtype: object

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 0        12:00:00                    0 2010-01-03 12:00:00
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
#ocorrências do ano de 2015 e mês 12, onde o dia é maior ou igual a 3 e menor ou igual a 8
filtro_dia_ano = df.ocorrencia_dia_hora.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia_hora.dt.month == 12
filtro_dia_inicio = df.ocorrencia_dia_hora.dt.day > 2
filtro_dia_fim = df.ocorrencia_dia_hora.dt.day < 9
df.loc[filtro_dia_ano & filtro_dia_mes & filtro_dia_inicio & filtro_dia_fim ]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
#ocorrências filtro por data 

filtro_dia_inicio = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro_dia_fim = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'
df.loc[filtro_dia_inicio & filtro_dia_fim]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3441              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3435    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436          TRINDADE            GO                  NaN     2015-12-06
# 3437         AMERICANA            SP                 SDAI     2015-12-06
# 3439             JALES            SP                 SDJL     2015-12-08
# 3441     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# ...

# %%
#ocorrência do ano 2015 e mês 03

filtro_dia_ano = df.ocorrencia_dia_hora.dt.year == 2015
filtro_dia_mes = df.ocorrencia_dia_hora.dt.month == 3
df201503 = df.loc[filtro_dia_ano & filtro_dia_mes]
df201503
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3088              53183               53183                 ACIDENTE
# 3089              53120               53120                 ACIDENTE
# 3090              53109               53109                 ACIDENTE
# 3091              53112               53112                 ACIDENTE
# 3092              53152               53152          INCIDENTE GRAVE
# 3093              53167               53167                INCIDENTE
# 3094              53596               53596                INCIDENTE
# 3095              53149               53149                 ACIDENTE
# 3096              53148               53148                 ACIDENTE
# 3097              53153               53153                INCIDENTE
# 3098              53154               53154                INCIDENTE
# 3099              53238               53238                INCIDENTE
# 3100              53189               53189                INCIDENTE
# ...

# %%
df201503.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
#Agrupando os dados e contagem desses dados

df201503.groupby(['codigo_ocorrencia']).count()
# Out:
#                    codigo_ocorrencia2  ocorrencia_classificacao  \
# codigo_ocorrencia
# 53109                               1                         1
# 53112                               1                         1
# 53120                               1                         1
# 53148                               1                         1
# 53149                               1                         1
# 53151                               1                         1
# 53152                               1                         1
# 53153                               1                         1
# 53154                               1                         1
# 53164                               1                         1
# 53165                               1                         1
# 53166                               1                         1
# 53167                               1                         1
# ...

# %%
#Agrupando os dados e contagem desses dados

df201503.groupby(['codigo_ocorrencia']).codigo_ocorrencia.count()
# Out:
# codigo_ocorrencia
# 53109    1
# 53112    1
# 53120    1
# 53148    1
# 53149    1
# 53151    1
# 53152    1
# 53153    1
# 53154    1
# 53164    1
# 53165    1
# 53166    1
# 53167    1
# 53168    1
# 53169    1
# 53170    1
# 53178    1
# 53179    1
# 53180    1
# 53181    1
# 53182    1
# 53183    1
# 53184    1
# 53185    1
# 53186    1
# 53187    1
# 53188    1
# 53189    1
# 53190    1
# 53193    1
# 53194    1
# 53211    1
# 53212    1
# 53213    1
# 53238    1
# 53412    1
# 53596    1
# Name: codigo_ocorrencia, dtype: int64

# %%
#Agrupamento da coluna ocorrencia_classificacao e contagem de dado de codigo_ocorrencia

df201503.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
#Agrupamento da coluna ocorrencia_classificacao e contagem de dado de codigo_ocorrencia (Pode gerar erro pois em dados nulos- Está Errado !!!)

df201503.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
#Agrupamento da coluna ocorrencia_classificacao e contagem com a função SIZE,que informa o número de linhas  

df201503.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#Agrupamento da coluna ocorrencia_classificacao e contagem com a função SIZE,que informa o número de linhas e Ordenação crescente 

df201503.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
#Agrupamento da coluna ocorrencia_classificacao e contagem com a função SIZE,que informa o número de linhas e Ordenação decrescente 

df201503.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#ocorrência do ano 2010

filtro_dia_ano = df.ocorrencia_dia.dt.year == 2010
filtro_uf = df.ocorrencia_uf.isin(['SP', 'MG', 'ES', 'RJ'])
dfsudeste2010 = df.loc[filtro_dia_ano & filtro_uf]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# ...

# %%
#Total de ocorrência classificadas na região SUDESTE e agrupadas por ocorrências

dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
#Contagem dos dados referente ao agrupamento dos dados para região sudeste "A SOMA DO CAMPO OCORRENCIA_CLASSIFICACACAO" É IGUAL AO GROUPBY DA REGIÃO SUDESTE" TOTAL 228

dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
#Total de ocorrência classificadas na região SUDESTE e por ESTADO e agrupadas por ocorrências

dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf' ]).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
#Total de ocorrência classificadas na região SUDESTE e por ESTADO e agrupadas por ocorrências

dfsudeste2010.groupby(['ocorrencia_uf','ocorrencia_classificacao' ]).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             INCIDENTE                    5
# MG             ACIDENTE                     7
#                INCIDENTE                   39
#                INCIDENTE GRAVE              5
# RJ             ACIDENTE                     9
#                INCIDENTE                   52
#                INCIDENTE GRAVE              4
# SP             ACIDENTE                    24
#                INCIDENTE                   74
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
#Filtr de ocorrência classificadas por cidade e ocorrencia_classificada e ordenadas maior quantidade de ocorrência

dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# JUIZ DE FORA              4
# VITÓRIA                   4
# MARÍLIA                   3
# SÃO JOSÉ DOS CAMPOS       3
# SÃO JOSÉ DO RIO PRETO     3
# SOROCABA                  2
# ITANHAÉM                  2
# RIBEIRÃO PRETO            2
# IPATINGA                  2
# POÇOS DE CALDAS           2
# DIVINÓPOLIS               2
# BAURU                     2
# JUNDIAÍ                   2
# ARARAQUARA                2
# CAMPOS DOS GOYTACAZES     2
# AREALVA                   2
# MONTES CLAROS             2
# UBERABA                   2
# POUSO ALEGRE              1
# PIRACICABA                1
# PIRASSUNUNGA              1
# ARRAIAL DO CABO           1
# RESENDE                   1
# PENÁPOLIS                 1
# ...

# %%
#Ocorrencias classificadas no Rio de Janeiro sem agrupamento

filtro = dfsudeste2010.ocorrencia_cidade =='RIO DE JANEIRO'
dfsudeste2010.loc[filtro]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 19               44575               44575                INCIDENTE
# 23               40311               40311                INCIDENTE
# 24               41577               41577                INCIDENTE
# 30               39849               39849                INCIDENTE
# 39               40617               40617                INCIDENTE
# 49               39295               39295                 ACIDENTE
# 71               39987               39987                INCIDENTE
# 101              40210               40210                INCIDENTE
# 105              40209               40209                INCIDENTE
# 107              40330               40330                INCIDENTE
# 119              40190               40190                INCIDENTE
# ...

# %%
# Total de Recomendações que o Rio de Janeiro teve

filtro = dfsudeste2010.ocorrencia_cidade =='RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
# Total de Recomendações que o Rio de Janeiro teve - Validação

filtro1 = dfsudeste2010.ocorrencia_cidade =='RIO DE JANEIRO'
filtro2 = dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 119              40190               40190                INCIDENTE
# 274              41750               41750                 ACIDENTE
# 326              42250               42250                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 119    RIO DE JANEIRO            RJ                 SBGL     2010-04-06
# 274    RIO DE JANEIRO            RJ                 SBJR     2010-07-12
# 326    RIO DE JANEIRO            RJ                 SBRJ     2010-08-12
#
#     ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 119        02:35:00                    3 2010-04-06 02:35:00
# 274        19:53:00                    3 2010-07-12 19:53:00
# 326        12:26:00                   19 2010-08-12 12:26:00

# %%
# Total de Recomendações por cidade da região sudeste

dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# AMERICANA                 0
# ARARAQUARA                0
# ARAÇATUBA                 0
# AREALVA                   0
# ARRAIAL DO CABO           0
# BAURU                     0
# BEBEDOURO                 0
# BELO HORIZONTE            2
# BOCAINA                   0
# BOITUVA                   1
# BOM JESUS DO AMPARO       0
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# BROTAS                    0
# CAJOBI                    0
# CAMANDUCAIA               9
# CAMPINAS                  0
# CAMPOS DOS GOYTACAZES     0
# CASIMIRO DE ABREU         0
# CONFINS                   0
# COROMANDEL                0
# COSMÓPOLIS                0
# DIAMANTINA                0
# DIVINÓPOLIS               0
# GUARULHOS                 0
# IPATINGA                  0
# IPERÓ                     3
# ITANHAÉM                  1
# ITÁPOLIS                  0
# JUIZ DE FORA              0
# JUNDIAÍ                   7
# LINHARES                  0
# ...

# %%
# Total de Recomendações por aerodromo da região sudeste

dfsudeste2010.groupby(['ocorrencia_aerodromo']).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# Name: total_recomendacoes, dtype: int64

# %%
# Total de Recomendações por aerodromo da região sudeste sem os aerodromos que não foram informados

dfsudeste2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# NaN     45
# Name: total_recomendacoes, dtype: int64

# %%
# Filtro de cidades SUDESTE que tem recomandações 

filtro = dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# BELO HORIZONTE            2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# IPERÓ                     3
# ITANHAÉM                  1
# JUNDIAÍ                   7
# NOVO HORIZONTE            3
# RESENDE                   8
# RIO DE JANEIRO           25
# SÃO BERNARDO DO CAMPO     2
# SÃO PAULO                41
# TIMÓTEO                   3
# Name: total_recomendacoes, dtype: int64

# %%
# Filtro de cidades SUDESTE que tem recomandações ordenadas de forma crescente de recomendações

filtro = dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values()
# Out:
# ocorrencia_cidade
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# JUNDIAÍ                   7
# RESENDE                   8
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RIO DE JANEIRO           25
# SÃO PAULO                41
# Name: total_recomendacoes, dtype: int64

# %%
# Filtro de cidades SUDESTE que tem recomandações ordenadas de forma decrescente de recomendações

filtro = dfsudeste2010.total_recomendacoes > 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# SÃO PAULO                41
# RIO DE JANEIRO           25
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# RESENDE                   8
# JUNDIAÍ                   7
# IPERÓ                     3
# NOVO HORIZONTE            3
# TIMÓTEO                   3
# BELO HORIZONTE            2
# SÃO BERNARDO DO CAMPO     2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# ITANHAÉM                  1
# Name: total_recomendacoes, dtype: int64

# %%
#Agrupamento por mêses ordenando pela cidade

dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# BRAGANÇA PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# IPERÓ                  1                  3
# ITANHAÉM               9                  1
# JUNDIAÍ                5                  5
#                        6                  2
# NOVO HORIZONTE         7                  3
# RESENDE                4                  8
# RIO DE JANEIRO         4                  3
#                        7                  3
#                        8                 19
# SÃO BERNARDO DO CAMPO  1                  2
# SÃO PAULO              1                  8
#                        2                 14
#                        6                  2
#                        11                 6
# ...

# %%
#Filtro de Agrupamento com dados da ocorrência de São Paulo e que se comparando com filtro de cidade está correto

filtro1 = dfsudeste2010.total_recomendacoes > 0 
filtro2 = dfsudeste2010.ocorrencia_cidade == 'SÃO PAULO'
dfsudeste2010.loc[filtro1 & filtro2]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11               40069               40069                 ACIDENTE
# 58               39275               39275                 ACIDENTE
# 63               39992               39992                 ACIDENTE
# 219              41411               41411          INCIDENTE GRAVE
# 469              43450               43450                 ACIDENTE
# 530              43471               43471                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 11          SÃO PAULO            SP                 SBMT     2010-01-10
# 58          SÃO PAULO            SP                  NaN     2010-02-10
# 63          SÃO PAULO            SP                 SBMT     2010-02-17
# 219         SÃO PAULO            SP                 SBMT     2010-06-08
# 469         SÃO PAULO            SP                 SBMT     2010-11-04
# ...
