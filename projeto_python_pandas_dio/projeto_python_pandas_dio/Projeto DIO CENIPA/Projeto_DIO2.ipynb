# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importando a biblioteca pandas
import pandas as pd

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_train.csv",sep=",")
df2 = pd.read_csv("/content/sample_data/mnist_test.csv",sep=",")

# %%
df = pd.concat([df1, df2])

# %%
# Exibição da 
df.head()
# Out:
#    longitude  latitude  housing_median_age  ...  0.665  0.666  0.667
# 0    -114.31     34.19                15.0  ...    NaN    NaN    NaN
# 1    -114.47     34.40                19.0  ...    NaN    NaN    NaN
# 2    -114.56     33.69                17.0  ...    NaN    NaN    NaN
# 3    -114.57     33.64                14.0  ...    NaN    NaN    NaN
# 4    -114.57     33.57                20.0  ...    NaN    NaN    NaN
#
# [5 rows x 794 columns]

# %%
#Renomeadno as colunas 

df.rename(columns= {'longitude':'Posicao_Longitude', 'latitude':'Posicao_Latitude', 'housing_median_age':'Media_Idade_Casa', 'total_rooms':'Total_Salas', 'total_bedrooms':'Total_Quartos', 'population':'População', 'households':'Familias', 'median_income	':'Renda_Media', 'median_house_value':'Media_Valor_Casa'})
# Out:
#       Posicao_Longitude  Posicao_Latitude  ...  0.666  0.667
# 0               -114.31             34.19  ...    NaN    NaN
# 1               -114.47             34.40  ...    NaN    NaN
# 2               -114.56             33.69  ...    NaN    NaN
# 3               -114.57             33.64  ...    NaN    NaN
# 4               -114.57             33.57  ...    NaN    NaN
# ...                 ...               ...  ...    ...    ...
# 9994                NaN               NaN  ...    0.0    0.0
# 9995                NaN               NaN  ...    0.0    0.0
# 9996                NaN               NaN  ...    0.0    0.0
# 9997                NaN               NaN  ...    0.0    0.0
# 9998                NaN               NaN  ...    0.0    0.0
#
# [26999 rows x 794 columns]

# %%
df.shape
# Out:
# (26999, 794)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
#                        ...
# 0.663                 float64
# 0.664                 float64
# 0.665                 float64
# 0.666                 float64
# 0.667                 float64
# Length: 794, dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', '7',
#        ...
#        '0.658', '0.659', '0.660', '0.661', '0.662', '0.663', '0.664', '0.665',
#        '0.666', '0.667'],
#       dtype='object', length=794)

# %%
df.tail(15)
# Out:
#       longitude  latitude  housing_median_age  ...  0.665  0.666  0.667
# 9984        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9985        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9986        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9987        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9988        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9989        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9990        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9991        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9992        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9993        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9994        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# 9995        NaN       NaN                 NaN  ...    0.0    0.0    0.0
# ...

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age  ...   0.665   0.666   0.667
# count  17000.000000  17000.000000        17000.000000  ...  9999.0  9999.0  9999.0
# mean    -119.562108     35.625225           28.589353  ...     0.0     0.0     0.0
# std        2.005166      2.137340           12.586937  ...     0.0     0.0     0.0
# min     -124.350000     32.540000            1.000000  ...     0.0     0.0     0.0
# 25%     -121.790000     33.930000           18.000000  ...     0.0     0.0     0.0
# 50%     -118.490000     34.250000           29.000000  ...     0.0     0.0     0.0
# 75%     -118.000000     37.720000           37.000000  ...     0.0     0.0     0.0
# max     -114.310000     41.950000           52.000000  ...     0.0     0.0     0.0
#
# [8 rows x 794 columns]

# %%
df["longitude"].unique()
# Out:
# array([-114.31, -114.47, -114.56, -114.57, -114.58, -114.59, -114.6 ,
#        -114.61, -114.63, -114.65, -114.66, -114.67, -114.68, -114.73,
#        -114.94, -114.98, -115.22, -115.32, -115.37, -115.38, -115.39,
#        -115.4 , -115.41, -115.46, -115.48, -115.49, -115.5 , -115.51,
#        -115.52, -115.53, -115.54, -115.55, -115.56, -115.57, -115.58,
#        -115.59, -115.6 , -115.62, -115.64, -115.69, -115.72, -115.73,
#        -115.8 , -115.84, -115.85, -115.88, -115.9 , -115.91, -115.93,
#        -115.94, -115.95, -115.96, -115.98, -115.99, -116.  , -116.01,
#        -116.02, -116.05, -116.06, -116.08, -116.09, -116.11, -116.12,
#        -116.14, -116.15, -116.16, -116.17, -116.18, -116.19, -116.2 ,
#        -116.21, -116.22, -116.23, -116.24, -116.25, -116.26, -116.27,
#        -116.29, -116.3 , -116.31, -116.32, -116.33, -116.34, -116.35,
#        -116.36, -116.37, -116.38, -116.39, -116.4 , -116.41, -116.42,
# ...

# %%
lon = df.loc[df["longitude"]== -123.32]
lon.head()
# Out:
#        longitude  latitude  housing_median_age  ...  0.665  0.666  0.667
# 16834    -123.32     40.43                15.0  ...    NaN    NaN    NaN
# 16835    -123.32     39.42                22.0  ...    NaN    NaN    NaN
#
# [2 rows x 794 columns]

# %%
lon['longitude'].unique
# Out:
# <bound method Series.unique of 16834   -123.32
# 16835   -123.32
# Name: longitude, dtype: float64>

# %%
df.groupby('median_house_value')['housing_median_age'].nunique()
# Out:
# median_house_value
# 14999.0      4
# 17500.0      1
# 22500.0      3
# 25000.0      1
# 26600.0      1
#             ..
# 498800.0     1
# 499000.0     1
# 499100.0     1
# 500000.0    13
# 500001.0    51
# Name: housing_median_age, Length: 3694, dtype: int64

# %%
#Media de Quartos
df["total_bedrooms"].mean()
# Out:
# 539.4108235294118

# %%
#Consultando os dados nulos

df.isnull().sum()
# Out:
# longitude              9999
# latitude               9999
# housing_median_age     9999
# total_rooms            9999
# total_bedrooms         9999
#                       ...
# 0.663                 17000
# 0.664                 17000
# 0.665                 17000
# 0.666                 17000
# 0.667                 17000
# Length: 794, dtype: int64

# %%
#Substituindo os valores nulos por zero
df["0"].fillna(0, inplace=True)

# %%
#Excluir as linhas com valores nulos
#df.dropna(inplace=True)

# %%
#Excluir as linhas com valores nulos com base em uma unica coluna
#df.dropna(subset =["0.3"], inplace=True)

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  ...  0.665  0.666  0.667
# 0     -114.31     34.19                15.0  ...    NaN    NaN    NaN
# 1     -114.47     34.40                19.0  ...    NaN    NaN    NaN
# 2     -114.56     33.69                17.0  ...    NaN    NaN    NaN
# 3     -114.57     33.64                14.0  ...    NaN    NaN    NaN
# 4     -114.57     33.57                20.0  ...    NaN    NaN    NaN
# 5     -114.58     33.63                29.0  ...    NaN    NaN    NaN
# 6     -114.58     33.61                25.0  ...    NaN    NaN    NaN
# 7     -114.59     34.83                41.0  ...    NaN    NaN    NaN
# 8     -114.59     33.61                34.0  ...    NaN    NaN    NaN
# 9     -114.60     34.83                46.0  ...    NaN    NaN    NaN
# 10    -114.60     33.62                16.0  ...    NaN    NaN    NaN
# 11    -114.60     33.60                21.0  ...    NaN    NaN    NaN
# ...

# %%
df["median_house_value"].mean
# Out:
# <bound method Series.mean of 0       66900.0
# 1       80100.0
# 2       85700.0
# 3       73400.0
# 4       65500.0
#          ...
# 9994        NaN
# 9995        NaN
# 9996        NaN
# 9997        NaN
# 9998        NaN
# Name: median_house_value, Length: 26999, dtype: float64>

# %%
#Mostrar o gráfico sem linhas horizontais do menor para maior
df["median_house_value"].value_counts(ascending=True).plot.barh()
